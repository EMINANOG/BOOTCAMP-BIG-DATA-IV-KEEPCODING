# %% [markdown]
# #**Análisis en Test.**

# %%
# Primero cargamos librerías y funciones necesarias
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt # para dibujar
# %matplotlib inline


#Para trabajar en el colab
from google.colab import drive
drive.mount('/content/drive')

# Cargamos el fichero de  generado en el colab anterior
airbnbMadrid_test = pd.read_csv('/content/drive/My Drive/BootCamp - BigDataIV - DL/PracticaDL-Regresion/test.csv', sep=';', decimal='.') # cargamos fichero test en un dataset
airbnbMadrid_train = pd.read_csv('/content/drive/My Drive/BootCamp - BigDataIV - DL/PracticaDL-Regresion/train.csv', sep=';', decimal='.') # cargamos fichero train en un dataset

#atributos que no nos aporta información, así que los descartamos :
airbnbMadrid_test = airbnbMadrid_test.drop(['ID'], axis=1)
airbnbMadrid_test = airbnbMadrid_test.drop(['Listing Url'], axis=1)
airbnbMadrid_test = airbnbMadrid_test.drop(['Scrape ID'], axis=1)
airbnbMadrid_test = airbnbMadrid_test.drop(['Last Scraped'], axis=1)
airbnbMadrid_test = airbnbMadrid_test.drop(['Name'], axis=1)
airbnbMadrid_test = airbnbMadrid_test.drop(['City'], axis=1)
airbnbMadrid_test = airbnbMadrid_test.drop(['Summary'], axis=1)
airbnbMadrid_test = airbnbMadrid_test.drop(['Space'], axis=1)
airbnbMadrid_test = airbnbMadrid_test.drop(['Description'], axis=1)
airbnbMadrid_test = airbnbMadrid_test.drop(['Experiences Offered'], axis=1)
airbnbMadrid_test = airbnbMadrid_test.drop(['Neighborhood Overview'], axis=1)
airbnbMadrid_test = airbnbMadrid_test.drop(['Notes'], axis=1)
airbnbMadrid_test = airbnbMadrid_test.drop(['Transit'], axis=1)
airbnbMadrid_test = airbnbMadrid_test.drop(['Access'], axis=1)
airbnbMadrid_test = airbnbMadrid_test.drop(['Interaction'], axis=1)
airbnbMadrid_test = airbnbMadrid_test.drop(['House Rules'], axis=1)
airbnbMadrid_test = airbnbMadrid_test.drop(['Thumbnail Url'], axis=1)
airbnbMadrid_test = airbnbMadrid_test.drop(['Medium Url'], axis=1)
airbnbMadrid_test = airbnbMadrid_test.drop(['Picture Url'], axis=1)
airbnbMadrid_test = airbnbMadrid_test.drop(['XL Picture Url'], axis=1)
airbnbMadrid_test = airbnbMadrid_test.drop(['Host ID'], axis=1)
airbnbMadrid_test = airbnbMadrid_test.drop(['Host URL'], axis=1)
airbnbMadrid_test = airbnbMadrid_test.drop(['Host Name'], axis=1)
airbnbMadrid_test = airbnbMadrid_test.drop(['Host Since'], axis=1)
airbnbMadrid_test = airbnbMadrid_test.drop(['Host Location'], axis=1)
airbnbMadrid_test = airbnbMadrid_test.drop(['Host About'], axis=1)
airbnbMadrid_test = airbnbMadrid_test.drop(['Host Response Time'], axis=1)
airbnbMadrid_test = airbnbMadrid_test.drop(['Host Response Rate'], axis=1)
airbnbMadrid_test = airbnbMadrid_test.drop(['Host Acceptance Rate'], axis=1)
airbnbMadrid_test = airbnbMadrid_test.drop(['Host Thumbnail Url'], axis=1)
airbnbMadrid_test = airbnbMadrid_test.drop(['Host Picture Url'], axis=1)
airbnbMadrid_test = airbnbMadrid_test.drop(['Host Neighbourhood'], axis=1)
airbnbMadrid_test = airbnbMadrid_test.drop(['Host Listings Count'], axis=1)
airbnbMadrid_test = airbnbMadrid_test.drop(['Host Total Listings Count'], axis=1)
airbnbMadrid_test = airbnbMadrid_test.drop(['Host Verifications'], axis=1)
airbnbMadrid_test = airbnbMadrid_test.drop(['Street'], axis=1)
airbnbMadrid_test = airbnbMadrid_test.drop(['Latitude'], axis=1)
airbnbMadrid_test = airbnbMadrid_test.drop(['Longitude'], axis=1)
airbnbMadrid_test = airbnbMadrid_test.drop(['Calendar last Scraped'], axis=1)
airbnbMadrid_test = airbnbMadrid_test.drop(['Last Review'], axis=1)
airbnbMadrid_test = airbnbMadrid_test.drop(['License'], axis=1)
airbnbMadrid_test = airbnbMadrid_test.drop(['Jurisdiction Names'], axis=1)
airbnbMadrid_test = airbnbMadrid_test.drop(['First Review'], axis=1)
airbnbMadrid_test = airbnbMadrid_test.drop(['Geolocation'], axis=1)
airbnbMadrid_test = airbnbMadrid_test.drop(['Features'], axis=1)
airbnbMadrid_test = airbnbMadrid_test.drop(['Amenities'], axis=1)

#la variable Has_Availability_mean_enc sólo tiene 8 registros, por lo que se elimina directamente
airbnbMadrid_test = airbnbMadrid_test.drop(['Has Availability'], axis=1)

airbnbMadrid_test.info() #queda dtypes: float64(18), int64(10), object(15)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2655 entries, 0 to 2654
# Data columns (total 43 columns):
# Accommodates                      2655 non-null int64
# Availability 30                   2655 non-null int64
# Availability 365                  2655 non-null int64
# Availability 60                   2655 non-null int64
# Availability 90                   2655 non-null int64
# Bathrooms                         2647 non-null float64
# ...

# %%
# Sustituimos los missings por la media en caso que la variable(numérica) tenga nulos : 
airbnbMadrid_test["Bedrooms"] = airbnbMadrid_test["Bedrooms"].fillna(airbnbMadrid_test["Bedrooms"].mean())
airbnbMadrid_test["Bathrooms"] = airbnbMadrid_test["Bathrooms"].fillna(airbnbMadrid_test["Bathrooms"].mean())
airbnbMadrid_test["Beds"] = airbnbMadrid_test["Beds"].fillna(airbnbMadrid_test["Beds"].mean())
airbnbMadrid_test["Square Feet"] = airbnbMadrid_test["Square Feet"].fillna(airbnbMadrid_test["Square Feet"].mean())
airbnbMadrid_test["Price"] = airbnbMadrid_test["Price"].fillna(airbnbMadrid_test["Price"].mean())
airbnbMadrid_test["Weekly Price"] = airbnbMadrid_test["Weekly Price"].fillna(airbnbMadrid_test["Weekly Price"].mean())
airbnbMadrid_test["Monthly Price"] = airbnbMadrid_test["Monthly Price"].fillna(airbnbMadrid_test["Monthly Price"].mean())
airbnbMadrid_test["Security Deposit"] = airbnbMadrid_test["Security Deposit"].fillna(airbnbMadrid_test["Security Deposit"].mean())
airbnbMadrid_test["Cleaning Fee"] = airbnbMadrid_test["Cleaning Fee"].fillna(airbnbMadrid_test["Cleaning Fee"].mean())
airbnbMadrid_test["Review Scores Rating"] = airbnbMadrid_test["Review Scores Rating"].fillna(airbnbMadrid_test["Review Scores Rating"].mean())
airbnbMadrid_test["Review Scores Accuracy"] = airbnbMadrid_test["Review Scores Accuracy"].fillna(airbnbMadrid_test["Review Scores Accuracy"].mean())
airbnbMadrid_test["Review Scores Cleanliness"] = airbnbMadrid_test["Review Scores Cleanliness"].fillna(airbnbMadrid_test["Review Scores Cleanliness"].mean())
airbnbMadrid_test["Review Scores Checkin"] = airbnbMadrid_test["Review Scores Checkin"].fillna(airbnbMadrid_test["Review Scores Checkin"].mean())
airbnbMadrid_test["Review Scores Communication"] = airbnbMadrid_test["Review Scores Communication"].fillna(airbnbMadrid_test["Review Scores Communication"].mean())
airbnbMadrid_test["Review Scores Value"] = airbnbMadrid_test["Review Scores Value"].fillna(airbnbMadrid_test["Review Scores Value"].mean())
airbnbMadrid_test["Review Scores Location"] = airbnbMadrid_test["Review Scores Location"].fillna(airbnbMadrid_test["Review Scores Location"].mean())
airbnbMadrid_test["Calculated host listings count"] = airbnbMadrid_test["Calculated host listings count"].fillna(airbnbMadrid_test["Calculated host listings count"].mean())
airbnbMadrid_test["Reviews per Month"] = airbnbMadrid_test["Reviews per Month"].fillna(airbnbMadrid_test["Reviews per Month"].mean())

# %%
# Convertimos la variable de superficie de pies al cuadrado a metros al cuadrado.
feetFeatures = ['Square Feet']
airbnbMadrid_test[feetFeatures] = airbnbMadrid_test[feetFeatures].apply(lambda x: x * 0.3048 * 0.3048)
#Renombramos la columna
airbnbMadrid_test = airbnbMadrid_test.rename(columns={'Square Feet':'SquareM2'})

# %% [markdown]
# ## Categorización de varibles.
# Usamos el método mean encoder para las variables no categorizadas.

# %%
#Hay 15 variables a categorizar : float64(18), int64(10), object(15)

mean_encode = airbnbMadrid_train.groupby('Neighbourhood')['Price'].mean()
airbnbMadrid_test.loc[:,'Neighbourhood_mean_enc']=airbnbMadrid_test['Neighbourhood'].map(mean_encode)

mean_encode = airbnbMadrid_train.groupby('Neighbourhood Cleansed')['Price'].mean()
airbnbMadrid_test.loc[:,'Neighbourhood_Cleansed_mean_enc']=airbnbMadrid_test['Neighbourhood Cleansed'].map(mean_encode)

mean_encode = airbnbMadrid_train.groupby('Neighbourhood Group Cleansed')['Price'].mean()
airbnbMadrid_test.loc[:,'Neighbourhood_Group_Cleansed_mean_enc']=airbnbMadrid_test['Neighbourhood Group Cleansed'].map(mean_encode)

mean_encode = airbnbMadrid_train.groupby('State')['Price'].mean()
airbnbMadrid_test.loc[:,'State_mean_enc']=airbnbMadrid_test['State'].map(mean_encode)

mean_encode = airbnbMadrid_train.groupby('Zipcode')['Price'].mean()
airbnbMadrid_test.loc[:,'Zipcode_mean_enc']=airbnbMadrid_test['Zipcode'].map(mean_encode)

mean_encode = airbnbMadrid_train.groupby('Market')['Price'].mean()
airbnbMadrid_test.loc[:,'Market_mean_enc']=airbnbMadrid_test['Market'].map(mean_encode)

mean_encode = airbnbMadrid_train.groupby('Smart Location')['Price'].mean()
airbnbMadrid_test.loc[:,'Smart_Location_mean_enc']=airbnbMadrid_test['Smart Location'].map(mean_encode)

mean_encode = airbnbMadrid_train.groupby('Country Code')['Price'].mean()
airbnbMadrid_test.loc[:,'Country_Code_mean_enc']=airbnbMadrid_test['Country Code'].map(mean_encode)

mean_encode = airbnbMadrid_train.groupby('Country')['Price'].mean()
airbnbMadrid_test.loc[:,'Country_mean_enc']=airbnbMadrid_test['Country'].map(mean_encode)

mean_encode = airbnbMadrid_train.groupby('Property Type')['Price'].mean()
airbnbMadrid_test.loc[:,'Property_Type_mean_enc']=airbnbMadrid_test['Property Type'].map(mean_encode)

mean_encode = airbnbMadrid_train.groupby('Room Type')['Price'].mean()
airbnbMadrid_test.loc[:,'Room_Type_mean_enc']=airbnbMadrid_test['Room Type'].map(mean_encode)

mean_encode = airbnbMadrid_train.groupby('Bed Type')['Price'].mean()
airbnbMadrid_test.loc[:,'Bed_Type_mean_enc']=airbnbMadrid_test['Bed Type'].map(mean_encode)

mean_encode = airbnbMadrid_train.groupby('Calendar Updated')['Price'].mean()
airbnbMadrid_test.loc[:,'Calendar_Updated_mean_enc']=airbnbMadrid_test['Calendar Updated'].map(mean_encode)

mean_encode = airbnbMadrid_train.groupby('Cancellation Policy')['Price'].mean()
airbnbMadrid_test.loc[:,'Cancellation_Policy_mean_enc']=airbnbMadrid_test['Cancellation Policy'].map(mean_encode)

# %%
#Creamos un dataset sólo con variables categoricas para análisis exploratorio
airbnbMadrid_test2 = airbnbMadrid_test.copy()

airbnbMadrid_test2 = airbnbMadrid_test2.drop(['Neighbourhood'], axis=1)
airbnbMadrid_test2 = airbnbMadrid_test2.drop(['Neighbourhood Cleansed'], axis=1)
airbnbMadrid_test2 = airbnbMadrid_test2.drop(['Neighbourhood Group Cleansed'], axis=1)
airbnbMadrid_test2 = airbnbMadrid_test2.drop(['State'], axis=1)
airbnbMadrid_test2 = airbnbMadrid_test2.drop(['Zipcode'], axis=1)
airbnbMadrid_test2 = airbnbMadrid_test2.drop(['Market'], axis=1)
airbnbMadrid_test2 = airbnbMadrid_test2.drop(['Smart Location'], axis=1)
airbnbMadrid_test2 = airbnbMadrid_test2.drop(['Country Code'], axis=1)
airbnbMadrid_test2 = airbnbMadrid_test2.drop(['Country'], axis=1)
airbnbMadrid_test2 = airbnbMadrid_test2.drop(['Property Type'], axis=1)
airbnbMadrid_test2 = airbnbMadrid_test2.drop(['Room Type'], axis=1)
airbnbMadrid_test2 = airbnbMadrid_test2.drop(['Bed Type'], axis=1)
airbnbMadrid_test2 = airbnbMadrid_test2.drop(['Calendar Updated'], axis=1)
airbnbMadrid_test2 = airbnbMadrid_test2.drop(['Cancellation Policy'], axis=1)

# %%
#Las nuevas variables categorizadas tiene nulos. Se sustituyen por la media.
airbnbMadrid_test2["Neighbourhood_mean_enc"] = airbnbMadrid_test2["Neighbourhood_mean_enc"].fillna(airbnbMadrid_test2["Neighbourhood_mean_enc"].mean())
airbnbMadrid_test2["Neighbourhood_Group_Cleansed_mean_enc"] = airbnbMadrid_test2["Neighbourhood_Group_Cleansed_mean_enc"].fillna(airbnbMadrid_test["Neighbourhood_Group_Cleansed_mean_enc"].mean())
airbnbMadrid_test2["State_mean_enc"] = airbnbMadrid_test2["State_mean_enc"].fillna(airbnbMadrid_test2["State_mean_enc"].mean())
airbnbMadrid_test2["Zipcode_mean_enc"] = airbnbMadrid_test2["Zipcode_mean_enc"].fillna(airbnbMadrid_test2["Zipcode_mean_enc"].mean())
airbnbMadrid_test2["Market_mean_enc"] = airbnbMadrid_test2["Market_mean_enc"].fillna(airbnbMadrid_test2["Market_mean_enc"].mean())
airbnbMadrid_test2["Country_mean_enc"] = airbnbMadrid_test2["Country_mean_enc"].fillna(airbnbMadrid_test2["Country_mean_enc"].mean())

# %%
airbnbMadrid_test2.reindex(sorted(airbnbMadrid_test2.columns), axis=1)
# Out:
#       Accommodates  Availability 30  ...  Weekly Price  Zipcode_mean_enc
# 0                2                5  ...    366.625187         86.346591
# 1                1                0  ...    366.625187         60.862745
# 2                1                0  ...    366.625187         60.520710
# 3                2               11  ...    366.625187         41.250000
# 4                4               11  ...    366.625187         67.718457
# ...            ...              ...  ...           ...               ...
# 2650             2                8  ...    547.000000         86.346591
# 2651             1                0  ...    366.625187         60.862745
# 2652             6                4  ...    840.000000         84.121472
# 2653             1                0  ...    366.625187         84.121472
# 2654             2               13  ...    366.625187         67.718457
#
# [2655 rows x 43 columns]

# %%
#Puede verse una alta correlación entre Availability60, y 30, y entre 60 y 90. Es lógico, ya que si está disponible 90 días, 
#también lo está 60 y 30, y si lo está 60, lo está 30. Así que resulta lógico eliminar la disponibilidad 60 y 90 días.
airbnbMadrid_test2 = airbnbMadrid_test2.drop(['Availability 60'], axis=1)
airbnbMadrid_test2 = airbnbMadrid_test2.drop(['Availability 90'], axis=1)
#Puede verse una alta correlación entre Smart_location y City, que coindicen casi siempre. Se elimina Smart_Location. 
airbnbMadrid_test2 = airbnbMadrid_test2.drop(['Smart_Location_mean_enc'], axis=1)
#Puede verse una alta correlación entre Country y Country_Code, debido a que uno es la abreviatura del otro. Se elimina pues, 
#Country.
airbnbMadrid_test2 = airbnbMadrid_test2.drop(['Country_mean_enc'], axis=1)
#Beds y Accommodates es muy alta, de 0.82, pues hay muy alta relación de número de acomodados con el número de camas. Pero al
#no llegar a 0.9, no se descarta.

# %%
#Muestra por pantalla el dataset filtrado
airbnbMadrid_test2.reindex(sorted(airbnbMadrid_test2.columns), axis=1)
# Out:
#       Accommodates  Availability 30  ...  Weekly Price  Zipcode_mean_enc
# 0                2                5  ...    366.625187         86.346591
# 1                1                0  ...    366.625187         60.862745
# 2                1                0  ...    366.625187         60.520710
# 3                2               11  ...    366.625187         41.250000
# 4                4               11  ...    366.625187         67.718457
# ...            ...              ...  ...           ...               ...
# 2650             2                8  ...    547.000000         86.346591
# 2651             1                0  ...    366.625187         60.862745
# 2652             6                4  ...    840.000000         84.121472
# 2653             1                0  ...    366.625187         84.121472
# 2654             2               13  ...    366.625187         67.718457
#
# [2655 rows x 39 columns]

# %%
# Guardamos en archivos de salida
airbnbMadrid_test2.to_csv('/content/drive/My Drive/BootCamp - BigDataIV - DL/PracticaDL-Regresion/test2-reg.csv', sep=';', decimal='.', index=False)
